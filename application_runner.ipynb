# %% [markdown]
# ### **Configuring the Python Environment**

# %%
#Install Streamlit Application
# !pip install streamlit pyngrok

# %%
#Connect Google drive
from google.colab import drive
drive.mount('/content/drive')
#Mount application path
# %cd '/content/drive/MyDrive/AgileEmo_Application-HostApp/'

# %% [markdown]
# ### **Run Streamlit Application**

# %% [markdown]
# ##### **NGROK Tunnel for Deploy Application**

# %%
import os

from threading import Thread
from pyngrok import ngrok

#Change your Token key here
ngrok.set_auth_token('2kw7myd4zowLKXNzyCpHrD9Jy1H_3Udxu6MPqCcqRhV96nUNH')

# %%
def run_streamlit():
  os.system('streamlit run /content/drive/MyDrive/AgileEmo_Application/app.py --server.port 8501')

_thread = Thread(target=run_streamlit)
_thread.start()

# %%
_public_url = ngrok.connect(addr='8501', proto='http', bind_tls=True)
print('Your Streamlit app is Live at: ', _public_url)

# %% [markdown]
# ##### **Remote Server Tunnel for Development**

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.19.88.82

# %%
# !streamlit run app.py & npx localtunnel --port 8501

# %% [markdown]
# ### **Application Hosting Support**

# %%
# !pip install pipreqs

# %%
# !pipreqs ./
